# %% [markdown]
# Lista 1

# %% [markdown]
# A

# %%
E,T=input().split()
# Out:
# 4 2

# %%
E=int(E)

# %%
T=int(T)

# %%
V = E//T

# %%
print(V)
# Out:
# 2

# %% [markdown]
# B

# %%
A,B,C,D,E=input().split()
# Out:
# 100 20 20 10 5

# %%
A=int(A)

# %%
B=int(B)

# %%
C=int(C)

# %%
D=int(D)

# %%
E=int(E)

# %%
I=A-(B+C+D+E)

# %%
print(int(I))
# Out:
# 45

# %% [markdown]
# C

# %%
K,J,H=input().split()
# Out:
# 1 1 1

# %%
M,N,O=input().split()
# Out:
# 1 1 1

# %%
K=int(K)

# %%
J=int(J)

# %%
H=int(H)

# %%
M=int(M)

# %%
N=int(N)

# %%
O=int(O)

# %%
print(K+M,J+N,H+O)
# Out:
# (2, 2, 2)

# %% [markdown]
# D

# %%
L,Z,N,U,S=input().split()
# Out:
# 1 1 1 1 1

# %%
L=int(L)

# %%
Z=int(Z)

# %%
N=int(N)

# %%
U=int(U)

# %%
S=int(S)

# %%
print(L+Z+N+U+S)
# Out:
# 5

# %% [markdown]
# E

# %%
N=int(input())
# Out:
# 543

# %%
print(N%10,int((N-N%10)/10)%10,int((((N-N%10)/10)-((N-N%10)/10)%10)/10))
# Out:
# 3 4 5

# %% [markdown]
# E

# %%
N=input()
# Out:
# 123

# %%
C=N[0]
D=N[1]
U=N[2]

# %%
C=int(C)
D=int(D)
U=int(U)

# %%
print('{:d} {:d} {:d}'.format(U,D,C))
# Out:
# 3 2 1

# %%
print('%d %d %d' % (U,D,C))
# Out:
# 3 2 1

# %% [markdown]
# F

# %%
S=int(input())
# Out:
# 5000

# %%
import datetime

# %%
m, s = divmod(S, 60)
h, m = divmod(m, 60)
print('{:d}h {:d}m {:d}s'.format(h, m, s))
# Out:
# 1h 23m 20s

# %% [markdown]
# F

# %%
S=int(input())
# Out:
# 135

# %%
h=S//3600
m=(S-(h*3600))//60
s=S%60

# %%
print('%dh %dm %ds'%(h,m,s))
# Out:
# 0h 2m 15s
