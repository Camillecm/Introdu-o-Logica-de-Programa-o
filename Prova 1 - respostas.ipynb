# %% [markdown]
# Prova 1

# %% [markdown]
# A

# %%
A,B,C,D=input().split()

# %%
A=int(A)
B=int(B)
C=int(C)
D=int(D)

# %%
print(A-3+B-3+C-3+D-3)

# %% [markdown]
# B

# %%
X,Y,R=input().split()

# %%
X=int(X)
Y=int(Y)
R=int(R)

# %%
D=2*R

# %%
l=X//D
c=Y//D

# %%
print(l*c)
