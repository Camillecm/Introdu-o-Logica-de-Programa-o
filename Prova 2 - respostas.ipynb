# %% [markdown]
# Prova 2

# %% [markdown]
# A

# %%
EC,AN,ES=input().split()
# Out:
# 5 40 2

# %%
EC=int(EC)
AN=int(AN)
ES=int(ES)

# %%
a=6-EC
b=60-AN
c=3-ES

# %%
if EC==6:
  print("Final Verdadeiro")
else:
  print("%d %d %d" % (a,b,c))
# Out:
# 1 20 1

# %%
if (EC==6):
  print("Final Verdadeiro")
else:
  print(6-EC, 60-AN, 3-ES)
# Out:
# 1 20 1

# %% [markdown]
# B

# %%
N=int(input())
# Out:
# 20

# %%
r=(N/3)-(N//3)

# %%
if N//3==N/3:
  print("Chapeuzinho Vermelho %d" % (N//3))
  print("Vovozinha %d" % (N//3))
  print("Lobo Mau %d" % (N//3))
else:
  if r<=1/2:
      print("Chapeuzinho Vermelho %d" % (N//3+1))
      print("Vovozinha %d" % (N//3))
      print("Lobo Mau %d" % (N//3))
  else:
      print("Chapeuzinho Vermelho %d" % ((N//3)+1))
      print("Vovozinha %d" % ((N//3)+1))
      print("Lobo Mau %d" % (N//3))
# Out:
# Chapeuzinho Vermelho 7
# Vovozinha 7
# Lobo Mau 6
